# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
time = [0.0875,0.1663,1.15458,1.9215,2.914,3.9475,4.0263,5.01458,5.7815,6.774,7.8075]
mag = [7.226016695374969,7.9339595599114245,8.263370140533295,8.322540592792826,7.407498898625751,
       7.226016695374969,7.9339595599114245,8.263370140533295,8.322540592792826,7.407498898625751,
      7.226016695374969]
magerror = [1.3403244343333631,0.7260599941010258,0.5402497666225572,
            0.6002828507803476,0.839648343874278,1.3403244343333631,0.7260599941010258,
            0.5402497666225572,0.6002828507803476,0.839648343874278,1.3403244343333631]
#plt.errorbar(time,mag,magerror,color='k',fmt='o')
plt.scatter(time,mag,color='k')
plt.grid()
plt.axis([-1,9,9,7])
plt.xlabel('Days')
plt.ylabel('Magnitude')
# Out:
# Text(0, 0.5, 'Magnitude')

# %%
phase = []
for i in time:
    j = i/3.86
    phase.append(j)
plt.scatter(phase,mag,color='k')
plt.plot(phase,mag,color='k')
plt.grid()
plt.axis([-0.1,2.1,8.6,7])
# Out:
# [-0.1, 2.1, 8.6, 7]
